# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt
 #bpp with m1 population 100 and 100
plt.plot([1, 2, 3, 4, 5], [44, 22, 36, 44, 36], label='N=10')
plt.plot([1, 2, 3, 4, 5], [216, 194, 222, 162, 182], label='N=100')
plt.legend()
plt.title('BPP1 Plots M1 Crossover N=10&100')
plt.xlabel('Number of Trials')
plt.ylabel('Fitness Values')
plt.savefig('comparison1.png')

# %%
Average fitness for bpp1: [44, 22, 36, 44, 36]
Average fitness for bpp1: [216, 194, 222, 162, 182]
Average fitness for bpp1: [456, 476, 400, 490, 418]
Average fitness for bpp1: [744, 702, 552, 756, 684]
Average fitness for bpp1: [3056, 4040, 3126, 4222, 3632]
Average fitness for bpp1: [1434, 1920, 5302, 3884, 2996]
Average fitness for bpp1: [332056, 297648, 310593, 368447, 326641]
Average fitness for bpp1: [532783, 545682, 611220, 517504, 523314]
Average fitness for bpp1: [332400, 330884, 315221, 317178, 298160]
Average fitness for bpp1: [468774, 480423, 512291, 474760, 521118]
Average fitness for bpp1: [795322, 801467, 842960, 819534, 795807]
Average fitness for bpp1: [795850, 813486, 807075, 786248, 813248]
[1, 2, 3, 4, 5]
195.2

# %%
 #bpp with m1 population 100 and 100
plt.plot([1, 2, 3, 4, 5], [456, 476, 400, 490, 418], label='N=10')
plt.plot([1, 2, 3, 4, 5], [744, 702, 552, 756, 684], label='N=100')
plt.legend()
plt.title('BPP1 Plots M5 Crossover N=10&100')
plt.xlabel('Number of Trials')
plt.ylabel('Fitness Values')
# Out:
# Text(0, 0.5, 'Fitness Values')

# %%
plt.plot([1, 2, 3, 4, 5], [3056, 4040, 3126, 4222, 3632], label='Only M5')
plt.plot([1, 2, 3, 4, 5], [456, 476, 400, 490, 418], label='Crossover')
plt.legend()
plt.title('BPP1 Plots M5 Crossover and No Crossover N=10')
plt.xlabel('Number of Trials')
plt.ylabel('Fitness Values')
# Out:
# Text(0, 0.5, 'Fitness Values')

# %%
 #bpp1 with  cross over and not population 10
plt.plot([1, 2, 3, 4, 5], [44, 22, 36, 44, 36], label='BPP1')
plt.plot([1, 2, 3, 4, 5], [332056, 297648, 310593, 368447, 326641], label='BPP2')
plt.legend()
plt.title('BPP comparasion Pop size = 10')
plt.xlabel('Number of Trials')
plt.ylabel('Fitness Values')
plt.savefig('BPPCompare.png')

# %%
 #bpp1 with  m5 and not population 10
 #bpp1 with  cross over and not population 10
plt.plot([1, 2, 3, 4, 5], [1434, 1920, 5302, 3884, 2996], label='Experiment6')
plt.plot([1, 2, 3, 4, 5], [456, 476, 400, 490, 418], label='Experiment3')
plt.legend()
plt.title('BPP1 Only Crossover and pop size = 10')
plt.xlabel('Number of Trials')
plt.ylabel('Fitness Values')
plt.savefig('Crossover.png')
